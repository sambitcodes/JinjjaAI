# %% [markdown]
# # QLoRA Quantized Fine-Tuning Pipeline\n**Objective:** Utilize 4-bit quantization via bitsandbytes to train massive foundation models (e.g. Qwen 14B) on a single RTX 4080.\n---\nOptimized for NVIDIA GeForce RTX 4080 (16GB VRAM) leveraging CUDA, PyTorch, and PEFT libraries.

# %%
import torch
from transformers import BitsAndBytesConfig, AutoModelForCausalLM

# Define NF4 4-bit quantization parameters
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

print("Quantization config successfully initialized. Feasible for RTX 4080 (16GB VRAM).")
