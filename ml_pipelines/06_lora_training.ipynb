# %% [markdown]
# # LoRA Parameter-Efficient Fine-Tuning\n**Objective:** Train specialized low-rank adaptation layers with PEFT to adapt larger Qwen/Exaone foundation models on RTX 4080.\n---\nOptimized for NVIDIA GeForce RTX 4080 (16GB VRAM) leveraging CUDA, PyTorch, and PEFT libraries.

# %%
import torch
from peft import LoraConfig, get_peft_model
from transformers import AutoModelForCausalLM

model_name = "Qwen/Qwen2.5-7B"
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# Setup model under PEFT configurations
print("PEFT config loaded successfully mapping targets:", peft_config.target_modules)
