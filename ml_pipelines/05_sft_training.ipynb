# %% [markdown]
# # Supervised Fine-Tuning SFT Pipeline\n**Objective:** Train custom instruction models using native PyTorch loops, HuggingFace Accelerate, and deep optimization templates.\n---\nOptimized for NVIDIA GeForce RTX 4080 (16GB VRAM) leveraging CUDA, PyTorch, and PEFT libraries.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer
from datasets import Dataset

print("Initializing PyTorch SFT loop on GPU:", torch.cuda.get_device_name(0))

# Load lightweight base model for demonstration
model_name = "Qwen/Qwen2.5-1.5B-Instruct"
tokenizer = AutoTokenizer.from_name = model_name
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

# Run simple training arguments
training_args = TrainingArguments(
    output_dir="./sft_output",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    learning_rate=2e-5,
    logging_steps=10,
    max_steps=50,
    fp16=True,
    report_to="none"
)
print("Trainer configuration loaded.")
